# %% [markdown]
# # Demographic Visual Seaborn

# %%
import pandas as pd
Mydata = pd.read_csv("DemographicData.csv")

# %% [markdown]
# Mydata.columns = ['CountryName', 'CountryCode', 'Birthrate', 'InternetUsers',
#        'IncomeGroup']
# Mydata.head()

# %%
import seaborn as sns
import matplotlib as plt
# %matplotlib inline
import warnings 
warnings.filterwarnings("ignore")
plt.rcParams["figure.figsize"] = 8,4
vis1 = sns.distplot(Mydata["InternetUsers"], bins = 30)

# %% [markdown]
# ## Box plot()

# %%
vis2 = sns.boxplot(data=Mydata, y="InternetUsers", x= "IncomeGroup")

# %% [markdown]
# # lmplot()

# %%
vis3 = sns.lmplot(data= Mydata, x = "InternetUsers" , y ="Birthrate", fit_reg = False , hue = "IncomeGroup")

# %%
vis4 = sns.lmplot(data= Mydata, x = "InternetUsers" , y ="Birthrate", fit_reg = False , hue = "IncomeGroup", size= 10, aspect = 3)

# %%
vis5 = sns.lmplot(data= Mydata, x = "InternetUsers" , y ="Birthrate",\
                  fit_reg = False , hue = "IncomeGroup", size= 10,\
                  aspect = 3, scatter_kws = {"s" :300})

# %%
vis4 = sns.jointplot(data = Mydata, x = "InternetUsers" , y ="Birthrate")
